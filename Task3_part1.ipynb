# %% [markdown]
# <a href="https://colab.research.google.com/github/Respectus11/DataScience_Bootcamp/blob/master/Task3_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'Name': ['Kalab', 'Yosef', 'Beti', 'Hamza', 'Yitbarek', 'Abebe',
             'Mekdes', 'Samuel', 'Selam', 'Nahom', 'Hiwot', 'Fitsum',
             'Meron', 'Bereket', 'Lidya'],
    'Age': list(range(18, 33)),
    'Department': ['CSE', 'SE', 'EPCE', 'ECEC', 'ARC', 'WATER', 'MECH',
                   'CSE', 'SE', 'EPCE', 'ECEC', 'ARC', 'WATER', 'MECH', 'CSE'],
    'Salary': [5000, 7000, 9000, 11000, 13000, 15000, 17000,
               6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000],
    'Experience': [1, 2, 1, 3, 2, 4, 3, 1, 2, 3, 4, 2, 3, 1, 2]
}

# Create DataFrame
df_custom = pd.DataFrame(data, index=[f'Student{i}' for i in range(1, 16)])
print(df_custom)
# Out:
#                Name  Age Department  Salary  Experience
# Student1      Kalab   18        CSE    5000           1
# Student2      Yosef   19         SE    7000           2
# Student3       Beti   20       EPCE    9000           1
# Student4      Hamza   21       ECEC   11000           3
# Student5   Yitbarek   22        ARC   13000           2
# Student6      Abebe   23      WATER   15000           4
# Student7     Mekdes   24       MECH   17000           3
# Student8     Samuel   25        CSE    6000           1
# Student9      Selam   26         SE    8000           2
# Student10     Nahom   27       EPCE   10000           3
# Student11     Hiwot   28       ECEC   12000           4
# Student12    Fitsum   29        ARC   14000           2
# Student13     Meron   30      WATER   16000           3
# Student14   Bereket   31       MECH   18000           1
# Student15     Lidya   32        CSE   20000           2
